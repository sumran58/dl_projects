# %%
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvixaLdufWXQrva2XeWuZ9nRT_9vN2-futqA&s'
# Out:
# --2026-06-12 15:18:15--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvixaLdufWXQrva2XeWuZ9nRT_9vN2-futqA&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 108.177.12.102, 108.177.12.101, 108.177.12.113, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|108.177.12.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6849 (6.7K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcSvixaLdufWXQrva2XeWuZ9nRT_9vN2-futqA&s.1’
#
# images?q=tbn:ANd9Gc 100%[===================>]   6.69K  --.-KB/s    in 0s
#
# 2026-06-12 15:18:15 (61.9 MB/s) - ‘images?q=tbn:ANd9GcSvixaLdufWXQrva2XeWuZ9nRT_9vN2-futqA&s.1’ saved [6849/6849]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#loading the image through matplotlib.image module
img=mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
print(img)
# Out:
# [[[242 240 241]
#   [242 240 241]
#   [242 240 241]
#   ...
#   [230 224 224]
#   [230 224 224]
#   [230 224 224]]
#
#  [[242 240 241]
#   [242 240 241]
#   [242 240 241]
#   ...
#   [230 224 224]
#   [230 224 224]
#   [230 224 224]]
#
#  [[242 240 241]
#   [242 240 241]
#   [242 240 241]
#   ...
#   [230 224 224]
#   [230 224 224]
#   [230 224 224]]
#
#  ...
#
#  [[245 245 245]
#   [245 245 245]
#   [245 245 245]
#   ...
#   [227 221 223]
#   [227 221 223]
#   [225 219 221]]
#
#  [[245 245 245]
#   [245 245 245]
#   [245 245 245]
#   ...
#   [227 221 223]
#   [227 221 223]
#   [225 219 221]]
#
#  [[245 245 245]
#   [245 245 245]
#   [245 245 245]
#   ...
#   [227 221 223]
#   [227 221 223]
#   [227 221 223]]]

# %%
#displaying the image from numpy array
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
from PIL import Image

img = Image.open('/content/dog.jpg')
img_resize = img.resize((100, 100))

img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img_resize.save('dog_image_resize.jpg')

# %%
img_res=mpimg.imread('/content/dog_image_resize.jpg')
img_plot=plt.imshow(img_res)
plt.show()

# %%
img_res.shape
# Out:
# (100, 100, 3)

# %%
#converting rgb images to grayscale imgaes using opencv
import cv2
img=cv2.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
grayscale_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
type(grayscale_img)
# Out:
# numpy.ndarray

# %%
grayscale_img.shape
# Out:
# (225, 225)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(grayscale_img)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
cv2.imwrite('dog_grascale.jpg',grayscale_img)
# Out:
# True
